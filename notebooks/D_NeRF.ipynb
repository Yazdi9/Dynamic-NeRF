# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/albertpumarola/D-NeRF.git
# Out:
# fatal: destination path 'D-NeRF' already exists and is not an empty directory.

# %%
cd D-NeRF
# Out:
# /content/drive/MyDrive/D-NeRF

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.8/275.8 KB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.8/680.8 KB 45.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 KB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 KB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 KB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 80.8 MB/s eta 0:00:00
# ...

# %%
cd /content/drive/MyDrive/D-NeRF/torchsearchsorted
# Out:
# /content/drive/MyDrive/D-NeRF/torchsearchsorted

# %%
# !pip  install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/drive/MyDrive/D-NeRF/torchsearchsorted
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torchsearchsorted: filename=torchsearchsorted-1.1-cp39-cp39-linux_x86_64.whl size=6578514 sha256=20d3e1b1d4c84da4a153d6c668624c9b79197ef736a4570360d97cd5a6ff4b73
#   Stored in directory: /tmp/pip-ephem-wheel-cache-b566kdbr/wheels/1f/95/b8/c0107fb76ea006fff0d1aa2ff3db23756f7d4060ccaedd8911
# Successfully built torchsearchsorted
# ...

# %%
# !cd ..

# %%
# !unzip /content/drive/MyDrive/D-NeRF/data.zip
# Out:
# Archive:  /content/drive/MyDrive/D-NeRF/data.zip
# replace data/bouncingballs/transforms_train.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: data/bouncingballs/transforms_train.json
#   inflating: data/bouncingballs/val/r_012.png
#   inflating: data/bouncingballs/val/r_003.png
#   inflating: data/bouncingballs/val/r_017.png
#   inflating: data/bouncingballs/val/r_009.png
#   inflating: data/bouncingballs/val/r_006.png
#   inflating: data/bouncingballs/val/r_014.png
#   inflating: data/bouncingballs/val/r_005.png
#   inflating: data/bouncingballs/val/r_013.png
#   inflating: data/bouncingballs/val/r_001.png
#   inflating: data/bouncingballs/val/r_000.png
#   inflating: data/bouncingballs/val/r_018.png
#   inflating: data/bouncingballs/val/r_011.png
#   inflating: data/bouncingballs/val/r_007.png
#   inflating: data/bouncingballs/val/r_008.png
#   inflating: data/bouncingballs/val/r_019.png
#   inflating: data/bouncingballs/val/r_015.png
# ...

# %%
# !python /content/drive/MyDrive/D-NeRF/run_dnerf.py --config /content/drive/MyDrive/D-NeRF/configs/mutant.txt --render_only --render_test
# Out:
# 2023-04-08 17:41:24.510056: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-08 17:41:25.472705: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loaded blender (190, 400, 400, 4) torch.Size([40, 4, 4]) [400, 400, 555.5555155968841] /content/drive/MyDrive/D-NeRF/data/mutant
# NeRF type selected: direct_temporal
# Found ckpts []
# RENDER ONLY
# test poses shape torch.Size([20, 4, 4])
#   0% 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
# ...

# %%
# !python /content/drive/MyDrive/D-NeRF/run_dnerf.py --config /content/drive/MyDrive/D-NeRF/configs/mutant.txt
# Out:
# 2023-04-08 17:57:27.280318: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-08 17:57:28.144467: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loaded blender (190, 400, 400, 4) torch.Size([40, 4, 4]) [400, 400, 555.5555155968841] /content/drive/MyDrive/D-NeRF/data/mutant
# NeRF type selected: direct_temporal
# Found ckpts []
# Begin
#   0% 0/800000 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
